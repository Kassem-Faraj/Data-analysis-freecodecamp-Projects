# %%
import pandas as pd
df = pd.read_csv('./adult.data.csv')
df.head()
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 32556             0             0              38  United-States  <=50K
# ...

# %%
race_count = df['race'].value_counts()

#NIP
print(race_count)
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
#average age of men , not just age.
average_age_men = df.loc[df['sex'] == 'Male', 'age'].mean()
average_age_men
# Out:
# 39.43354749885268

# %%
education_count = df['education'].value_counts()
education_total = education_count.sum()
bachelor_total = education_count.iloc[2]
#Calculate in % total of bachelors degrees
percentage_bachelors = ((bachelor_total / education_total) * 100).round(1)
percentage_bachelors
# Out:
# 16.4

# %%
#Bachelors degree and salary > 50k
# df['salary'] = df['salary'].replace('[^0-9]', '', regex=True).astype(int)

advanced_education_count = df.loc[(df['education'] =='Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate') &
                           (df['salary'] >50)]
advanced_education = ((advanced_education_count.shape[0] / df.shape[0]) *100)
advanced_education
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       1 #Bachelors degree and salary > 50k
#       2 # df['salary'] = df['salary'].replace('[^0-9]', '', regex=True).astype(int)
#       4 advanced_education_count = df.loc[(df['education'] =='Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate') &
# ----> 5                            (df['salary'] >50)]
#       6 advanced_education = ((advanced_education_count.shape[0] / df.shape[0]) *100)
#       7 advanced_education
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
# ...

# %%
df_age = df['age'] + df['education-num']
print(df_age)

# %%
#Bachelors degree and salary > 50k
# df['salary'] = df['salary'].replace('[^0-9]', '', regex=True).astype(int)

advanced_education_count = df.loc[(df['education'] !='Bachelors') & (df['education'] != 'Masters') & (df['education'] != 'Doctorate')]
advanced_education_count
# advanced_education = ((advanced_education_count.shape[0] / df.shape[0]) *100)
# advanced_education
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...
